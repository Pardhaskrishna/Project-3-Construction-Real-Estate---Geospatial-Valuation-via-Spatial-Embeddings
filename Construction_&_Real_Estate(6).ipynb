# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
House = pd.read_csv("/content/data.csv")

# %%
House
# Out:
#             Date  Year       Locality  Estimated Value  Sale Price  \
# 0     2009-01-02  2009      Waterbury         111440.0    185000.0
# 1     2009-01-02  2009            NaN          73080.0    152000.0
# 2     2009-01-02  2009      Waterbury          50540.0    105000.0
# 3     2009-01-02  2009        Norwalk         571060.0   1000000.0
# 4     2009-01-02  2009     Bridgeport        4775276.0    272900.0
# ...          ...   ...            ...              ...         ...
# 9995  2022-09-30  2022            NaN         155550.0    215000.0
# 9996  2022-09-30  2022      Greenwich              NaN   2162500.0
# 9997  2022-09-30  2022  West Hartford         124740.0    225635.0
# 9998  2022-09-30  2022            NaN        1455230.0   2625000.0
# 9999  2022-09-30  2022        Norwalk         237880.0    430000.0
#
#            Property     Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Single Family  Detached House          3              3        996.0
# ...

# %%
House.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1768/2764694135.py in <cell line: 0>()
# ----> 1 House.info()
#
# NameError: name 'House' is not defined

# %%
House.describe()
# Out:
#                Year  Estimated Value    Sale Price     num_rooms  \
# count  10000.000000     8.771000e+03  1.000000e+04  10000.000000
# mean    2015.880100     4.445842e+05  6.224748e+05      3.329600
# std        4.088031     7.513565e+05  1.029709e+06      0.885123
# min     2009.000000     0.000000e+00  2.000000e+03      3.000000
# 25%     2012.000000     1.305250e+05  1.600000e+05      3.000000
# 50%     2016.000000     2.431800e+05  3.400000e+05      3.000000
# 75%     2019.000000     4.418300e+05  6.300000e+05      3.000000
# max     2022.000000     2.111991e+07  2.575000e+07      8.000000
#
#        num_bathrooms  carpet_area  property_tax_rate
# count   10000.000000  8718.000000       10000.000000
# mean        2.334000  1111.658981           1.143517
# std         1.209293   305.058455           0.166762
# min         1.000000   900.000000           1.003979
# 25%         1.000000   960.000000           1.023495
# 50%         2.000000  1021.000000           1.025899
# ...

# %%
House.dtypes
# Out:
# Date                  object
# Year                   int64
# Locality              object
# Estimated Value      float64
# Sale Price           float64
# Property              object
# Residential           object
# num_rooms              int64
# num_bathrooms          int64
# carpet_area          float64
# property_tax_rate    float64
# Face                  object
# dtype: object

# %%
House.isnull()
# Out:
#        Date   Year  Locality  Estimated Value  Sale Price  Property  \
# 0     False  False     False            False       False     False
# 1     False  False      True            False       False     False
# 2     False  False     False            False       False     False
# 3     False  False     False            False       False     False
# 4     False  False     False            False       False     False
# ...     ...    ...       ...              ...         ...       ...
# 9995  False  False      True            False       False     False
# 9996  False  False     False             True       False     False
# 9997  False  False     False            False       False     False
# 9998  False  False      True            False       False     False
# 9999  False  False     False            False       False     False
#
#       Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  \
# ...

# %%
House.isnull().sum()
# Out:
# Date                    0
# Year                    0
# Locality             1255
# Estimated Value      1229
# Sale Price              0
# Property                0
# Residential             0
# num_rooms               0
# num_bathrooms           0
# carpet_area          1282
# property_tax_rate       0
# Face                    0
# dtype: int64

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %%
House.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
House.duplicated().sum()
# Out:
# np.int64(0)

# %%
House.head()
# Out:
#          Date  Year    Locality  Estimated Value  Sale Price       Property  \
# 0  2009-01-02  2009   Waterbury         111440.0    185000.0  Single Family
# 1  2009-01-02  2009         NaN          73080.0    152000.0  Single Family
# 2  2009-01-02  2009   Waterbury          50540.0    105000.0  Single Family
# 3  2009-01-02  2009     Norwalk         571060.0   1000000.0  Single Family
# 4  2009-01-02  2009  Bridgeport        4775276.0    272900.0  Single Family
#
#       Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  \
# 0  Detached House          3              3        996.0           1.025953
# 1  Detached House          3              1        935.0           1.025953
# 2  Detached House          3              1        951.0           1.025953
# 3  Detached House          3              2          NaN           1.025953
# 4  Detached House          3              1        971.0           1.025953
#
#     Face
# 0  South
# 1  North
# 2   East
# ...

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %% [markdown]
# ## Day 2

# %%
sns.histplot(data=House,x="Sale Price")
# Out:
# <Axes: xlabel='Sale Price', ylabel='Count'>

# %%
sns.histplot(data=House,x="Sale Price")
# Out:
# <Axes: xlabel='Sale Price', ylabel='Count'>

# %%
sns.countplot(data=House,x="Property")
# Out:
# <Axes: xlabel='Property', ylabel='count'>

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %%
sns.scatterplot(data=House,x="Estimated Value",y="Sale Price")
# Out:
# <Axes: xlabel='Estimated Value', ylabel='Sale Price'>

# %%
sns.histplot(data=House,x="Residential")
# Out:
# <Axes: xlabel='Residential', ylabel='Count'>

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %% [markdown]
# ### 2nd push
# ### 3rd push

# %%
sns.scatterplot(data=House,x="Sale Price",y="Estimated Value")
# Out:
# <Axes: xlabel='Sale Price', ylabel='Estimated Value'>

# %%
sns.boxplot(data=House)
# Out:
# <Axes: >

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %%
sns.boxplot(data=House,x="Estimated Value")
# Out:
# <Axes: xlabel='Estimated Value'>

# %%
sns.boxplot(data=House,x="Sale Price")
# Out:
# <Axes: xlabel='Sale Price'>

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %% [markdown]
# ### 4th push

# %%
House['Estimated Value'].unique()
# Out:
# array([ 111440.,   73080.,   50540., ...,  124740., 1455230.,  237880.])

# %%
House['Sale Price'].unique()
# Out:
# array([ 185000.,  152000.,  105000., ..., 2360000., 2162500.,  225635.])

# %%
House['Property'].unique()
# Out:
# array(['Single Family', '?', 'Two Family', 'Three Family', 'Four Family'],
#       dtype=object)

# %%
House['Property'].unique()
# Out:
# array(['Single Family', '?', 'Two Family', 'Three Family', 'Four Family'],
#       dtype=object)

# %%
House['property_tax_rate'].unique()
# Out:
# array([1.025953 , 1.025846 , 1.025033 , 1.021958 , 1.020333 , 1.350819 ,
#        1.340225 , 1.348259 , 1.388283 , 1.422308 , 1.0258995, 1.0254395,
#        1.0234955, 1.003979 ])

# %%
House["Date"].unique()
# Out:
# array(['2009-01-02', '2009-01-03', '2009-01-04', ..., '2022-09-28',
#        '2022-09-29', '2022-09-30'], dtype=object)

# %% [markdown]
# ### 5th push

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %%
corr_matrix=House.corr(numeric_only=True)
plt.figure(figsize=(8,5))
sns.heatmap(corr_matrix,annot=True,cmap='cividis',fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %%
X = House.drop(columns=['Sale Price'])
y = House['Sale Price']

# %%
X
# Out:
#             Date  Year       Locality  Estimated Value       Property  \
# 0     2009-01-02  2009      Waterbury         111440.0  Single Family
# 1     2009-01-02  2009            NaN          73080.0  Single Family
# 2     2009-01-02  2009      Waterbury          50540.0  Single Family
# 3     2009-01-02  2009        Norwalk         571060.0  Single Family
# 4     2009-01-02  2009     Bridgeport        4775276.0  Single Family
# ...          ...   ...            ...              ...            ...
# 9995  2022-09-30  2022            NaN         155550.0   Three Family
# 9996  2022-09-30  2022      Greenwich              NaN  Single Family
# 9997  2022-09-30  2022  West Hartford         124740.0  Single Family
# 9998  2022-09-30  2022            NaN        1455230.0  Single Family
# 9999  2022-09-30  2022        Norwalk         237880.0              ?
#
#          Residential  num_rooms  num_bathrooms  carpet_area  \
# 0     Detached House          3              3        996.0
# ...

# %%
y
# Out:
# 0        185000.0
# 1        152000.0
# 2        105000.0
# 3       1000000.0
# 4        272900.0
#           ...
# 9995     215000.0
# 9996    2162500.0
# 9997     225635.0
# 9998    2625000.0
# 9999     430000.0
# Name: Sale Price, Length: 10000, dtype: float64

# %%
y.unique()
# Out:
# array([ 185000.,  152000.,  105000., ..., 2360000., 2162500.,  225635.])

# %% [markdown]
# ### Handling Imbalanced Data
# SMOTE- Synthetic Minority Over-sampling Technique
# SMOTE is a method for handling imbalanced datasets in machine learning.
# Goal: To increase the number of instances in the minority class by creating synthetic samples.
# How it works: SMOTE generates new examples by interpolating between existing minority class instances and their nearest neighbors.
# This helps the model learn better about the minority class and improves its performance on imbalanced datasets.

# %%
from collections import Counter

counts = Counter(y)
print(counts)
# Out:
# Counter({400000.0: 62, 160000.0: 61, 450000.0: 59, 150000.0: 59, 300000.0: 58, 250000.0: 56, 190000.0: 53, 125000.0: 53, 120000.0: 53, 200000.0: 52, 220000.0: 51, 130000.0: 50, 140000.0: 50, 500000.0: 48, 230000.0: 48, 165000.0: 48, 430000.0: 47, 180000.0: 47, 350000.0: 47, 100000.0: 46, 420000.0: 46, 325000.0: 44, 110000.0: 43, 90000.0: 43, 375000.0: 42, 380000.0: 42, 170000.0: 42, 410000.0: 41, 215000.0: 41, 175000.0: 41, 360000.0: 41, 475000.0: 40, 340000.0: 39, 280000.0: 39, 50000.0: 39, 240000.0: 37, 390000.0: 37, 75000.0: 36, 320000.0: 36, 135000.0: 36, 425000.0: 36, 275000.0: 36, 185000.0: 34, 195000.0: 34, 205000.0: 34, 60000.0: 34, 385000.0: 34, 260000.0: 34, 270000.0: 34, 315000.0: 34, 115000.0: 34, 30000.0: 34, 145000.0: 33, 395000.0: 33, 525000.0: 33, 575000.0: 33, 415000.0: 33, 155000.0: 33, 210000.0: 33, 285000.0: 32, 550000.0: 32, 225000.0: 32, 105000.0: 31, 330000.0: 31, 580000.0: 31, 310000.0: 31, 345000.0: 30, 235000.0: 29, 290000.0: 29, 485000.0: 29, 40000.0: 29, 4
# ...

# %%
House.columns
# Out:
# Index(['Date', 'Year', 'Locality', 'Estimated Value', 'Sale Price', 'Property',
#        'Residential', 'num_rooms', 'num_bathrooms', 'carpet_area',
#        'property_tax_rate', 'Face'],
#       dtype='object')

# %% [markdown]
# ### 6th push

# %%
House.drop(columns=['Date','Estimated Value','num_rooms','property_tax_rate','Sale Price'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3048/454529029.py in <cell line: 0>()
# ----> 1 House.drop(columns=['Date','Estimated Value','num_rooms','property_tax_rate','Sale Price'],inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
data=pd.DataFrame(scale.fit_transform(House),columns=House.columns,index=House.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3048/2958787803.py in <cell line: 0>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scale=StandardScaler()
# ----> 3 data=pd.DataFrame(scale.fit_transform(House),columns=House.columns,index=House.index)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...
